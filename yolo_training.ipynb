# %% [markdown]
# # YOLOv8 Model Training
#
# This notebook outlines the steps for training a YOLOv8 object detection model.

# %% [markdown]
# ### Installing and importing necessary libraries

# %%
# !pip install ultralytics
# !pip install squarify
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.21-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.5.0+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.20.0+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.9-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.21-py3-none-any.whl (877 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 877.1/877.1 kB 10.9 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.9-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.21 ultralytics-thop-2.0.9
# Collecting squarify
#   Downloading squarify-0.4.4-py3-none-any.whl.metadata (600 bytes)
# Downloading squarify-0.4.4-py3-none-any.whl (4.1 kB)
# Installing collected packages: squarify
# Successfully installed squarify-0.4.4

# %%
from google.colab import drive
from IPython import display
display.clear_output()
import ultralytics
ultralytics.checks()
from ultralytics import YOLO
from IPython.display import display, Image
import os
import cv2
from google.colab.patches import cv2_imshow
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.3/112.6 GB disk)

# %% [markdown]
# ### Connecting to Google Drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ###Model Initialization

# %%
model = YOLO(f'yolov8n.pt')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 302MB/s]

# %% [markdown]
# ###Creating and filling the data.yaml file for model training

# %% [markdown]
# [Link](https://drive.google.com/drive/folders/11SOUlzV8EtEKj157AEBhzxRMtbKz7x5T?usp=sharing) to the dataset that was used for training

# %%
# !touch data.yaml

# %% [markdown]
# > The file structure should look like this:
#
#
#
# ```
# train: /content/drive/MyDrive/dataset/train
#
# val: /content/drive/MyDrive/dataset/valid
#
# nc: 4
# ```

# %% [markdown]
# ###Starting training

# %%
results = model.train(
    data='data.yaml',
    epochs = 50,
    save=True,
    device = 'gpu',
    imgsz=640,
    save_period=1,
    project='/content/drive/MyDrive/yolov8_weights',
    name='project'
)

# %% [markdown]
# The final weights are called best.pt and are located in the folder
# ```
# /content/drive/MyDrive/yolov8_weights/project
# ```

# %%
#infer  = YOLO('/content/drive/MyDrive/AI_CHALLENGE_2/weights/wg.pt') # path to your weights

# %%
#!rm -r /content/runs # if predictions were ran previously

# %%
#infer.predict('/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0', save = True, save_txt  = True, conf = 0.5)
# Out:
# image 1/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2914.JPG: 480x640 300 class_1s, 36.8ms
# image 2/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2915.JPG: 480x640 300 class_1s, 7.1ms
# image 3/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2916.JPG: 480x640 288 class_1s, 7.5ms
# image 4/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2917.JPG: 480x640 300 class_1s, 8.9ms
# image 5/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2918.JPG: 480x640 295 class_0s, 5 class_1s, 6.8ms
# image 6/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2919.JPG: 480x640 300 class_1s, 6.9ms
# image 7/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2920.JPG: 480x640 300 class_1s, 9.5ms
# image 8/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2921.JPG: 480x640 300 class_1s, 7.4ms
# image 9/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2922.JPG: 480x640 219 class_1s, 6.9ms
# image 10/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2923.JPG: 480x640 127 class_0s, 6.7ms
# image 11/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2925.JPG: 480x640 300 class_0s, 7.0ms
# image 12/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2929.JPG: 480x640 269 class_1s, 6.7ms
# image 13/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2932.JPG: 480x640 300 class_1s, 6.9ms
# image 14/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2933.JPG: 480x640 300 class_1s, 13.6ms
# image 15/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2934.JPG: 480x640 285 class_1s, 8.6ms
# image 16/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2935.JPG: 480x640 300 class_1s, 6.9ms
# image 17/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2936.JPG: 480x640 126 class_0s, 7.3ms
# image 18/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2938.JPG: 480x640 300 class_0s, 8.2ms
# image 19/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2939.JPG: 480x640 300 class_0s, 13.8ms
# image 20/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2940.JPG: 480x640 300 class_0s, 7.0ms
# image 21/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2942.JPG: 480x640 300 class_0s, 6.8ms
# image 22/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2943.JPG: 480x640 136 class_0s, 6.8ms
# image 23/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2945.JPG: 480x640 178 class_0s, 11 class_1s, 6.9ms
# image 24/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2946.JPG: 480x640 300 class_0s, 12.0ms
# image 25/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2950.JPG: 480x640 300 class_1s, 11.3ms
# image 26/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2951.JPG: 480x640 300 class_1s, 6.7ms
# image 27/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2953.JPG: 480x640 142 class_0s, 7.0ms
# image 28/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2954.JPG: 480x640 144 class_0s, 6.8ms
# image 29/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2969.JPG: 480x640 281 class_1s, 7.4ms
# image 30/30 /content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/pipes2.jpeg: 640x640 75 class_0s, 8.1ms
# Speed: 3.2ms preprocess, 9.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 30 labels saved to runs/detect/predict/labels
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[140, 157, 160],
#          [157, 176, 179],
#          [233, 252, 255],
#          ...,
#          [ 95, 143, 201],
#          [ 95, 143, 201],
#          [ 95, 143, 201]],
#
#         [[139, 156, 159],
#          [159, 178, 181],
#          [233, 252, 255],
#          ...,
#          [ 95, 143, 201],
#          [ 95, 143, 201],
#          [ 95, 143, 201]],
#
#         [[137, 154, 157],
#          [162, 181, 184],
#          [235, 254, 255],
#          ...,
#          [ 95, 143, 201],
#          [ 95, 143, 201],
#          [ 95, 143, 201]],
#
#         ...,
#
#         [[149, 169, 170],
#          [149, 169, 170],
#          [150, 170, 171],
#          ...,
#          [ 12,  11,  15],
#          [ 19,  18,  22],
#          [ 26,  25,  29]],
#
#         [[149, 169, 170],
#          [149, 169, 170],
#          [150, 170, 171],
#          ...,
#          [ 13,  12,  14],
#          [ 17,  16,  18],
#          [ 23,  22,  24]],
#
#         [[149, 169, 170],
#          [149, 169, 170],
#          [150, 170, 171],
#          ...,
#          [ 13,  12,  14],
#          [ 15,  14,  16],
#          [ 20,  19,  21]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2914.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 17.61651039123535, 'inference': 36.82255744934082, 'postprocess': 1.7387866973876953},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[ 72,  78,  77],
#          [ 72,  78,  77],
#          [ 72,  77,  78],
#          ...,
#          [114, 165, 221],
#          [114, 165, 221],
#          [114, 165, 221]],
#
#         [[ 70,  76,  75],
#          [ 70,  76,  75],
#          [ 71,  76,  77],
#          ...,
#          [114, 165, 221],
#          [114, 165, 221],
#          [114, 165, 221]],
#
#         [[ 69,  74,  73],
#          [ 70,  75,  74],
#          [ 71,  75,  76],
#          ...,
#          [114, 165, 221],
#          [114, 165, 221],
#          [114, 165, 221]],
#
#         ...,
#
#         [[162, 152, 135],
#          [170, 160, 143],
#          [184, 172, 154],
#          ...,
#          [ 21,  14,  17],
#          [ 28,  19,  22],
#          [ 27,  18,  21]],
#
#         [[165, 157, 140],
#          [172, 164, 147],
#          [195, 188, 169],
#          ...,
#          [ 24,  17,  20],
#          [ 29,  20,  23],
#          [ 24,  15,  18]],
#
#         [[171, 164, 147],
#          [178, 171, 154],
#          [203, 197, 178],
#          ...,
#          [ 27,  20,  23],
#          [ 30,  21,  24],
#          [ 21,  12,  15]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2915.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.5205612182617188, 'inference': 7.124423980712891, 'postprocess': 1.4052391052246094},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[118, 150, 173],
#          [123, 157, 180],
#          [126, 160, 183],
#          ...,
#          [ 94, 135, 180],
#          [ 95, 136, 181],
#          [ 95, 136, 181]],
#
#         [[116, 148, 171],
#          [123, 155, 178],
#          [124, 158, 181],
#          ...,
#          [ 95, 136, 181],
#          [ 95, 136, 181],
#          [ 96, 137, 182]],
#
#         [[108, 139, 162],
#          [113, 145, 168],
#          [116, 150, 173],
#          ...,
#          [ 96, 137, 182],
#          [ 96, 137, 182],
#          [ 96, 137, 182]],
#
#         ...,
#
#         [[153, 124, 120],
#          [155, 126, 122],
#          [158, 129, 125],
#          ...,
#          [  9,   9,   9],
#          [ 13,  13,  13],
#          [ 18,  18,  18]],
#
#         [[155, 122, 119],
#          [161, 128, 125],
#          [167, 134, 131],
#          ...,
#          [ 21,  21,  21],
#          [ 22,  22,  22],
#          [ 25,  25,  25]],
#
#         [[163, 128, 125],
#          [161, 126, 123],
#          [161, 126, 123],
#          ...,
#          [ 30,  30,  30],
#          [ 32,  32,  32],
#          [ 35,  35,  35]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2916.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.5184154510498047, 'inference': 7.512331008911133, 'postprocess': 1.5034675598144531},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[146, 163, 166],
#          [151, 168, 171],
#          [149, 166, 169],
#          ...,
#          [104, 145, 194],
#          [104, 145, 194],
#          [104, 145, 194]],
#
#         [[147, 164, 167],
#          [152, 169, 172],
#          [150, 167, 170],
#          ...,
#          [103, 144, 193],
#          [103, 144, 193],
#          [103, 144, 193]],
#
#         [[150, 167, 170],
#          [154, 171, 174],
#          [150, 167, 170],
#          ...,
#          [103, 144, 193],
#          [103, 144, 193],
#          [103, 144, 193]],
#
#         ...,
#
#         [[121, 130, 133],
#          [122, 131, 134],
#          [122, 131, 134],
#          ...,
#          [ 40,  63,  71],
#          [ 37,  65,  72],
#          [ 52,  81,  88]],
#
#         [[122, 131, 134],
#          [121, 130, 133],
#          [122, 131, 134],
#          ...,
#          [ 37,  60,  68],
#          [ 36,  64,  71],
#          [ 49,  81,  87]],
#
#         [[127, 136, 139],
#          [123, 132, 135],
#          [122, 131, 134],
#          ...,
#          [ 31,  54,  62],
#          [ 29,  58,  65],
#          [ 42,  74,  80]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2917.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 3.661632537841797, 'inference': 8.944511413574219, 'postprocess': 1.8463134765625},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[138, 162, 168],
#          [192, 216, 222],
#          [181, 203, 209],
#          ...,
#          [ 52,  47,  49],
#          [ 45,  39,  40],
#          [ 33,  25,  25]],
#
#         [[138, 162, 168],
#          [190, 214, 220],
#          [185, 207, 213],
#          ...,
#          [ 48,  46,  52],
#          [ 38,  34,  39],
#          [ 25,  20,  22]],
#
#         [[134, 158, 164],
#          [182, 206, 212],
#          [188, 210, 216],
#          ...,
#          [ 31,  34,  48],
#          [ 29,  31,  42],
#          [  7,   8,  18]],
#
#         ...,
#
#         [[ 96, 139, 160],
#          [ 94, 137, 158],
#          [ 94, 139, 160],
#          ...,
#          [ 72, 108, 146],
#          [ 73, 109, 147],
#          [ 71, 107, 145]],
#
#         [[ 98, 141, 162],
#          [ 95, 138, 159],
#          [ 91, 136, 157],
#          ...,
#          [ 66, 103, 147],
#          [ 68, 105, 149],
#          [ 66, 103, 147]],
#
#         [[ 97, 140, 161],
#          [ 94, 137, 158],
#          [ 84, 129, 150],
#          ...,
#          [ 69, 108, 153],
#          [ 70, 109, 154],
#          [ 66, 105, 150]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2918.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.3462772369384766, 'inference': 6.773471832275391, 'postprocess': 2.2644996643066406},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[208, 207, 197],
#          [208, 207, 197],
#          [208, 207, 197],
#          ...,
#          [104, 172, 237],
#          [103, 171, 236],
#          [103, 171, 236]],
#
#         [[208, 207, 197],
#          [209, 208, 198],
#          [209, 208, 198],
#          ...,
#          [105, 173, 238],
#          [105, 173, 238],
#          [104, 172, 237]],
#
#         [[209, 208, 198],
#          [209, 208, 198],
#          [209, 208, 198],
#          ...,
#          [104, 172, 237],
#          [104, 172, 237],
#          [103, 171, 236]],
#
#         ...,
#
#         [[ 19,  29,  36],
#          [ 15,  27,  31],
#          [ 13,  28,  31],
#          ...,
#          [101, 185, 251],
#          [101, 185, 251],
#          [101, 185, 251]],
#
#         [[ 21,  33,  39],
#          [ 17,  29,  33],
#          [ 13,  28,  31],
#          ...,
#          [101, 185, 251],
#          [101, 185, 251],
#          [101, 185, 251]],
#
#         [[ 27,  39,  45],
#          [ 19,  31,  35],
#          [ 14,  29,  32],
#          ...,
#          [101, 185, 251],
#          [101, 185, 251],
#          [101, 185, 251]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2919.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.356290817260742, 'inference': 6.924867630004883, 'postprocess': 1.9335746765136719},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[ 66,  78,  78],
#          [ 63,  75,  75],
#          [ 68,  76,  76],
#          ...,
#          [ 75, 148, 222],
#          [ 77, 149, 226],
#          [ 78, 150, 227]],
#
#         [[ 89, 103, 102],
#          [ 75,  89,  88],
#          [ 67,  77,  77],
#          ...,
#          [ 76, 149, 223],
#          [ 78, 150, 227],
#          [ 79, 151, 228]],
#
#         [[124, 142, 143],
#          [101, 119, 120],
#          [ 79,  93,  92],
#          ...,
#          [ 77, 150, 224],
#          [ 77, 152, 228],
#          [ 79, 154, 230]],
#
#         ...,
#
#         [[  3,   9,   8],
#          [  2,   8,   7],
#          [  0,   5,   4],
#          ...,
#          [106, 163, 232],
#          [106, 163, 232],
#          [106, 163, 232]],
#
#         [[  0,   6,   5],
#          [  0,   6,   5],
#          [  0,   6,   5],
#          ...,
#          [107, 163, 234],
#          [107, 163, 234],
#          [107, 163, 234]],
#
#         [[  0,   4,   3],
#          [  0,   6,   5],
#          [  2,   8,   7],
#          ...,
#          [106, 162, 233],
#          [107, 162, 235],
#          [107, 162, 235]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2920.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.817392349243164, 'inference': 9.469032287597656, 'postprocess': 1.9831657409667969},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[126, 133, 136],
#          [126, 133, 136],
#          [128, 133, 136],
#          ...,
#          [136, 214, 227],
#          [140, 219, 232],
#          [137, 216, 229]],
#
#         [[126, 133, 136],
#          [126, 133, 136],
#          [128, 133, 136],
#          ...,
#          [147, 219, 236],
#          [125, 200, 216],
#          [ 99, 174, 188]],
#
#         [[128, 133, 136],
#          [128, 133, 136],
#          [128, 133, 136],
#          ...,
#          [117, 183, 202],
#          [ 94, 160, 179],
#          [ 75, 141, 159]],
#
#         ...,
#
#         [[ 82, 145, 195],
#          [ 82, 145, 195],
#          [ 82, 145, 195],
#          ...,
#          [158, 164, 175],
#          [136, 138, 149],
#          [111, 111, 123]],
#
#         [[ 77, 143, 192],
#          [ 77, 143, 192],
#          [ 77, 143, 192],
#          ...,
#          [157, 163, 176],
#          [134, 137, 151],
#          [115, 116, 130]],
#
#         [[ 74, 140, 189],
#          [ 75, 141, 190],
#          [ 75, 141, 190],
#          ...,
#          [113, 119, 132],
#          [101, 104, 118],
#          [101, 102, 116]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2921.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.4056434631347656, 'inference': 7.447004318237305, 'postprocess': 1.7635822296142578},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[ 58,  54,  43],
#          [ 60,  56,  45],
#          [ 64,  60,  49],
#          ...,
#          [180, 112, 105],
#          [177, 108,  99],
#          [174, 105,  96]],
#
#         [[ 47,  43,  32],
#          [ 50,  46,  35],
#          [ 54,  50,  39],
#          ...,
#          [180, 110, 103],
#          [177, 107, 100],
#          [175, 106,  97]],
#
#         [[ 39,  33,  22],
#          [ 42,  36,  25],
#          [ 46,  40,  29],
#          ...,
#          [179, 107, 100],
#          [178, 106,  99],
#          [178, 106,  99]],
#
#         ...,
#
#         [[ 29,  22,  19],
#          [ 26,  22,  17],
#          [ 29,  24,  21],
#          ...,
#          [ 23,  37,  49],
#          [ 23,  37,  49],
#          [ 22,  36,  48]],
#
#         [[ 76,  67,  63],
#          [ 63,  57,  50],
#          [ 54,  48,  43],
#          ...,
#          [ 20,  34,  46],
#          [ 21,  35,  47],
#          [ 22,  36,  48]],
#
#         [[170, 162, 155],
#          [144, 136, 129],
#          [111, 105,  98],
#          ...,
#          [ 19,  33,  45],
#          [ 21,  35,  47],
#          [ 24,  38,  50]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2922.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.368450164794922, 'inference': 6.931543350219727, 'postprocess': 1.524209976196289},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[181, 177, 172],
#          [184, 180, 175],
#          [186, 182, 177],
#          ...,
#          [111, 174, 224],
#          [110, 173, 223],
#          [110, 173, 223]],
#
#         [[185, 181, 176],
#          [184, 180, 175],
#          [184, 180, 175],
#          ...,
#          [111, 174, 224],
#          [110, 173, 223],
#          [110, 173, 223]],
#
#         [[189, 183, 178],
#          [186, 180, 175],
#          [183, 177, 172],
#          ...,
#          [110, 173, 223],
#          [109, 172, 222],
#          [109, 172, 222]],
#
#         ...,
#
#         [[ 51,  63,  81],
#          [ 41,  55,  73],
#          [ 32,  46,  65],
#          ...,
#          [ 18,  29,  43],
#          [ 19,  30,  44],
#          [ 19,  30,  44]],
#
#         [[ 32,  43,  63],
#          [ 40,  54,  73],
#          [ 44,  58,  77],
#          ...,
#          [ 18,  29,  43],
#          [ 17,  28,  42],
#          [ 16,  27,  41]],
#
#         [[ 45,  56,  76],
#          [ 47,  61,  80],
#          [ 37,  51,  70],
#          ...,
#          [ 18,  29,  43],
#          [ 16,  27,  41],
#          [ 15,  26,  40]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2923.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.385854721069336, 'inference': 6.693363189697266, 'postprocess': 1.4803409576416016},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[ 36,  47,  69],
#          [ 28,  42,  65],
#          [ 83, 103, 134],
#          ...,
#          [127, 139, 127],
#          [131, 146, 132],
#          [134, 149, 135]],
#
#         [[ 36,  47,  69],
#          [ 34,  48,  71],
#          [ 92, 113, 141],
#          ...,
#          [143, 154, 138],
#          [142, 153, 137],
#          [142, 153, 137]],
#
#         [[ 27,  36,  56],
#          [ 26,  38,  62],
#          [ 88, 107, 134],
#          ...,
#          [143, 149, 130],
#          [142, 148, 129],
#          [143, 150, 129]],
#
#         ...,
#
#         [[101, 182, 255],
#          [101, 182, 255],
#          [101, 183, 255],
#          ...,
#          [ 37,  57,  74],
#          [ 45,  65,  83],
#          [ 50,  70,  88]],
#
#         [[ 99, 182, 255],
#          [ 99, 182, 255],
#          [101, 182, 255],
#          ...,
#          [ 27,  47,  64],
#          [ 37,  57,  74],
#          [ 46,  66,  83]],
#
#         [[ 99, 182, 255],
#          [ 99, 182, 255],
#          [101, 182, 255],
#          ...,
#          [ 24,  44,  61],
#          [ 33,  53,  70],
#          [ 45,  65,  82]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2925.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.3033618927001953, 'inference': 7.025241851806641, 'postprocess': 1.9450187683105469},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[178, 169, 159],
#          [178, 169, 159],
#          [177, 168, 158],
#          ...,
#          [ 13,  44,  53],
#          [ 11,  38,  48],
#          [ 11,  39,  46]],
#
#         [[178, 169, 159],
#          [179, 170, 160],
#          [180, 171, 161],
#          ...,
#          [ 12,  41,  50],
#          [ 10,  37,  47],
#          [ 10,  38,  45]],
#
#         [[179, 170, 160],
#          [180, 171, 161],
#          [183, 174, 164],
#          ...,
#          [ 11,  38,  48],
#          [ 12,  37,  47],
#          [ 12,  38,  45]],
#
#         ...,
#
#         [[ 16,  18,  28],
#          [ 15,  17,  27],
#          [ 15,  17,  27],
#          ...,
#          [ 67, 132, 176],
#          [ 67, 130, 174],
#          [ 66, 129, 173]],
#
#         [[ 12,  14,  24],
#          [ 12,  14,  24],
#          [ 12,  14,  24],
#          ...,
#          [ 66, 132, 173],
#          [ 69, 131, 172],
#          [ 68, 130, 171]],
#
#         [[ 14,  16,  26],
#          [ 14,  16,  26],
#          [ 14,  16,  26],
#          ...,
#          [ 70, 134, 175],
#          [ 71, 133, 174],
#          [ 71, 131, 173]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2929.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.3207664489746094, 'inference': 6.677389144897461, 'postprocess': 1.4994144439697266},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[169, 152, 139],
#          [171, 154, 141],
#          [176, 160, 148],
#          ...,
#          [228, 164, 133],
#          [229, 158, 124],
#          [224, 150, 114]],
#
#         [[179, 162, 149],
#          [177, 160, 147],
#          [174, 158, 146],
#          ...,
#          [225, 161, 130],
#          [226, 155, 121],
#          [225, 151, 115]],
#
#         [[189, 173, 161],
#          [186, 170, 158],
#          [180, 164, 152],
#          ...,
#          [226, 162, 131],
#          [224, 153, 119],
#          [225, 151, 115]],
#
#         ...,
#
#         [[100, 212, 254],
#          [100, 212, 254],
#          [100, 212, 254],
#          ...,
#          [ 50,  80,  99],
#          [ 36,  63,  83],
#          [ 13,  40,  60]],
#
#         [[ 97, 209, 251],
#          [ 98, 210, 252],
#          [ 98, 210, 252],
#          ...,
#          [ 35,  66,  87],
#          [ 40,  69,  90],
#          [ 43,  72,  93]],
#
#         [[ 96, 208, 250],
#          [ 96, 208, 250],
#          [ 97, 209, 251],
#          ...,
#          [ 29,  62,  82],
#          [ 32,  63,  84],
#          [ 40,  71,  92]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2932.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.4123191833496094, 'inference': 6.874322891235352, 'postprocess': 1.5490055084228516},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[ 93, 120, 154],
#          [ 94, 121, 155],
#          [ 94, 122, 157],
#          ...,
#          [117, 157, 209],
#          [116, 156, 208],
#          [116, 156, 208]],
#
#         [[106, 133, 167],
#          [102, 129, 163],
#          [ 97, 125, 160],
#          ...,
#          [116, 157, 206],
#          [116, 156, 208],
#          [116, 157, 206]],
#
#         [[ 92, 120, 155],
#          [ 93, 121, 156],
#          [ 95, 123, 158],
#          ...,
#          [116, 158, 205],
#          [116, 157, 206],
#          [116, 158, 205]],
#
#         ...,
#
#         [[ 24,  45,  60],
#          [ 21,  42,  57],
#          [ 23,  44,  59],
#          ...,
#          [ 65,  69,  74],
#          [ 65,  69,  74],
#          [ 65,  69,  74]],
#
#         [[ 23,  46,  61],
#          [ 17,  40,  55],
#          [ 21,  44,  59],
#          ...,
#          [ 66,  70,  75],
#          [ 66,  70,  75],
#          [ 66,  70,  75]],
#
#         [[ 24,  47,  62],
#          [ 16,  39,  54],
#          [ 21,  44,  59],
#          ...,
#          [ 65,  69,  74],
#          [ 66,  70,  75],
#          [ 66,  70,  75]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2933.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 3.114461898803711, 'inference': 13.612508773803711, 'postprocess': 1.9774436950683594},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[155, 137, 130],
#          [154, 136, 129],
#          [154, 136, 129],
#          ...,
#          [108, 162, 217],
#          [108, 162, 217],
#          [108, 162, 217]],
#
#         [[155, 137, 130],
#          [154, 136, 129],
#          [154, 136, 129],
#          ...,
#          [108, 162, 217],
#          [108, 162, 217],
#          [108, 162, 217]],
#
#         [[154, 136, 129],
#          [154, 136, 129],
#          [153, 135, 128],
#          ...,
#          [108, 162, 217],
#          [108, 162, 217],
#          [108, 162, 217]],
#
#         ...,
#
#         [[  0,   2,  21],
#          [  1,   9,  26],
#          [ 10,  18,  35],
#          ...,
#          [210,  74,  40],
#          [210,  74,  40],
#          [210,  74,  40]],
#
#         [[  2,  11,  31],
#          [  7,  17,  35],
#          [ 12,  22,  40],
#          ...,
#          [210,  74,  40],
#          [210,  74,  40],
#          [210,  74,  40]],
#
#         [[ 21,  30,  50],
#          [ 23,  32,  52],
#          [ 24,  34,  52],
#          ...,
#          [210,  74,  40],
#          [210,  74,  40],
#          [210,  74,  40]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2934.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 3.7882328033447266, 'inference': 8.574724197387695, 'postprocess': 1.6350746154785156},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[ 14,  25,  33],
#          [ 12,  23,  31],
#          [ 11,  22,  30],
#          ...,
#          [ 72, 106, 135],
#          [ 82, 117, 143],
#          [ 89, 124, 150]],
#
#         [[ 14,  25,  33],
#          [ 13,  24,  32],
#          [ 11,  22,  30],
#          ...,
#          [111, 145, 174],
#          [126, 161, 187],
#          [135, 170, 196]],
#
#         [[ 15,  26,  34],
#          [ 13,  24,  32],
#          [ 12,  23,  31],
#          ...,
#          [131, 168, 194],
#          [130, 167, 193],
#          [130, 167, 193]],
#
#         ...,
#
#         [[ 68,  76,  89],
#          [ 58,  66,  79],
#          [ 49,  57,  70],
#          ...,
#          [107, 186, 253],
#          [108, 190, 255],
#          [106, 190, 255]],
#
#         [[ 63,  71,  84],
#          [ 52,  60,  73],
#          [ 49,  57,  70],
#          ...,
#          [108, 186, 253],
#          [106, 188, 255],
#          [108, 191, 255]],
#
#         [[ 57,  65,  78],
#          [ 49,  57,  70],
#          [ 50,  58,  71],
#          ...,
#          [112, 190, 255],
#          [107, 186, 255],
#          [105, 187, 255]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2935.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.430438995361328, 'inference': 6.9332122802734375, 'postprocess': 1.7006397247314453},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[127, 134, 137],
#          [127, 134, 137],
#          [126, 133, 136],
#          ...,
#          [ 92, 133, 178],
#          [ 91, 132, 177],
#          [ 90, 131, 176]],
#
#         [[126, 133, 136],
#          [125, 132, 135],
#          [125, 132, 135],
#          ...,
#          [ 95, 136, 181],
#          [ 95, 136, 181],
#          [ 95, 136, 181]],
#
#         [[124, 131, 134],
#          [124, 131, 134],
#          [124, 131, 134],
#          ...,
#          [ 94, 135, 180],
#          [ 95, 136, 181],
#          [ 95, 136, 181]],
#
#         ...,
#
#         [[ 66,  68,  76],
#          [ 69,  71,  79],
#          [ 65,  67,  75],
#          ...,
#          [ 25,  27,  35],
#          [ 33,  35,  43],
#          [ 44,  46,  54]],
#
#         [[ 57,  59,  67],
#          [ 59,  61,  69],
#          [ 53,  55,  63],
#          ...,
#          [ 29,  32,  40],
#          [ 35,  38,  46],
#          [ 42,  45,  53]],
#
#         [[ 14,  16,  24],
#          [ 16,  18,  26],
#          [ 17,  19,  27],
#          ...,
#          [ 31,  34,  42],
#          [ 35,  38,  46],
#          [ 39,  42,  50]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2936.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.4385452270507812, 'inference': 7.290840148925781, 'postprocess': 1.4772415161132812},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[ 22,  22,  22],
#          [ 26,  26,  26],
#          [ 26,  26,  26],
#          ...,
#          [163, 150, 152],
#          [164, 151, 153],
#          [165, 152, 154]],
#
#         [[ 33,  33,  33],
#          [ 30,  30,  30],
#          [ 28,  28,  28],
#          ...,
#          [159, 146, 148],
#          [160, 147, 149],
#          [160, 147, 149]],
#
#         [[ 37,  37,  37],
#          [ 20,  20,  20],
#          [ 14,  14,  14],
#          ...,
#          [159, 145, 147],
#          [160, 146, 148],
#          [160, 146, 148]],
#
#         ...,
#
#         [[ 35,  32,  41],
#          [ 29,  28,  37],
#          [  5,   8,  16],
#          ...,
#          [ 40,  43,  47],
#          [ 35,  38,  42],
#          [ 30,  33,  37]],
#
#         [[ 41,  40,  49],
#          [ 25,  27,  35],
#          [ 22,  28,  35],
#          ...,
#          [ 46,  49,  53],
#          [ 41,  44,  48],
#          [ 35,  38,  42]],
#
#         [[ 38,  37,  46],
#          [ 35,  37,  45],
#          [ 65,  71,  78],
#          ...,
#          [ 50,  53,  57],
#          [ 47,  50,  54],
#          [ 41,  44,  48]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2938.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.3491382598876953, 'inference': 8.240938186645508, 'postprocess': 2.0608901977539062},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[144, 173, 118],
#          [132, 161, 106],
#          [152, 181, 126],
#          ...,
#          [ 90,  81,  84],
#          [ 88,  79,  82],
#          [ 88,  79,  82]],
#
#         [[151, 179, 126],
#          [135, 163, 110],
#          [151, 179, 126],
#          ...,
#          [ 85,  76,  79],
#          [ 84,  75,  78],
#          [ 85,  76,  79]],
#
#         [[155, 181, 135],
#          [137, 163, 117],
#          [147, 173, 127],
#          ...,
#          [ 81,  72,  75],
#          [ 80,  71,  74],
#          [ 81,  72,  75]],
#
#         ...,
#
#         [[157, 160, 165],
#          [158, 161, 166],
#          [159, 162, 167],
#          ...,
#          [ 45,  43,  42],
#          [ 46,  44,  43],
#          [ 44,  42,  41]],
#
#         [[157, 160, 165],
#          [158, 161, 166],
#          [159, 162, 167],
#          ...,
#          [ 44,  42,  41],
#          [ 44,  42,  41],
#          [ 43,  41,  40]],
#
#         [[157, 160, 165],
#          [158, 161, 166],
#          [159, 162, 167],
#          ...,
#          [ 40,  38,  37],
#          [ 39,  37,  36],
#          [ 40,  38,  37]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2939.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 3.6971569061279297, 'inference': 13.813972473144531, 'postprocess': 2.4836063385009766},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[ 95,  99, 104],
#          [ 68,  74,  79],
#          [109, 117, 124],
#          ...,
#          [163, 170, 190],
#          [164, 171, 191],
#          [165, 172, 192]],
#
#         [[ 95,  99, 104],
#          [ 74,  80,  85],
#          [114, 122, 129],
#          ...,
#          [162, 169, 188],
#          [164, 169, 190],
#          [165, 172, 191]],
#
#         [[ 89,  93,  98],
#          [ 74,  80,  85],
#          [111, 119, 126],
#          ...,
#          [163, 170, 187],
#          [166, 170, 189],
#          [166, 173, 190]],
#
#         ...,
#
#         [[159, 185, 202],
#          [159, 185, 202],
#          [159, 185, 202],
#          ...,
#          [ 50,  54,  59],
#          [ 56,  60,  65],
#          [ 54,  58,  63]],
#
#         [[159, 185, 202],
#          [159, 185, 202],
#          [159, 185, 202],
#          ...,
#          [ 51,  55,  60],
#          [ 55,  61,  68],
#          [ 57,  63,  70]],
#
#         [[159, 185, 202],
#          [159, 185, 202],
#          [159, 185, 202],
#          ...,
#          [ 29,  33,  38],
#          [ 35,  41,  48],
#          [ 56,  62,  69]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2940.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.321004867553711, 'inference': 7.030487060546875, 'postprocess': 1.9900798797607422},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[ 46,  44,  43],
#          [ 46,  44,  43],
#          [ 47,  45,  44],
#          ...,
#          [173, 200, 227],
#          [173, 200, 227],
#          [173, 200, 227]],
#
#         [[ 47,  45,  44],
#          [ 46,  44,  43],
#          [ 45,  43,  42],
#          ...,
#          [173, 200, 227],
#          [173, 200, 227],
#          [173, 200, 227]],
#
#         [[ 48,  46,  45],
#          [ 46,  44,  43],
#          [ 43,  41,  40],
#          ...,
#          [173, 200, 227],
#          [173, 200, 227],
#          [173, 200, 227]],
#
#         ...,
#
#         [[ 27,  29,  29],
#          [ 27,  29,  29],
#          [ 27,  29,  29],
#          ...,
#          [231, 247, 255],
#          [233, 247, 255],
#          [200, 214, 226]],
#
#         [[ 27,  29,  29],
#          [ 28,  30,  30],
#          [ 27,  29,  29],
#          ...,
#          [185, 203, 214],
#          [220, 236, 248],
#          [235, 251, 255]],
#
#         [[ 28,  30,  30],
#          [ 28,  30,  30],
#          [ 27,  29,  29],
#          ...,
#          [139, 157, 168],
#          [179, 195, 207],
#          [231, 247, 255]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2942.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.3393630981445312, 'inference': 6.833076477050781, 'postprocess': 2.0928382873535156},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[ 53,  55,  55],
#          [ 54,  56,  56],
#          [ 54,  56,  56],
#          ...,
#          [155, 172, 199],
#          [155, 172, 199],
#          [155, 172, 199]],
#
#         [[ 54,  56,  56],
#          [ 54,  56,  56],
#          [ 54,  56,  56],
#          ...,
#          [155, 172, 199],
#          [155, 172, 199],
#          [155, 172, 199]],
#
#         [[ 55,  57,  57],
#          [ 55,  57,  57],
#          [ 55,  57,  57],
#          ...,
#          [153, 171, 200],
#          [155, 171, 200],
#          [155, 171, 200]],
#
#         ...,
#
#         [[ 40,  46,  45],
#          [ 34,  40,  39],
#          [ 30,  35,  34],
#          ...,
#          [ 26,  21,  23],
#          [ 31,  26,  28],
#          [ 32,  27,  29]],
#
#         [[ 41,  47,  46],
#          [ 29,  35,  34],
#          [ 23,  28,  27],
#          ...,
#          [ 26,  21,  23],
#          [ 28,  23,  25],
#          [ 27,  22,  24]],
#
#         [[ 42,  48,  47],
#          [ 25,  31,  30],
#          [ 20,  25,  24],
#          ...,
#          [ 26,  21,  23],
#          [ 25,  20,  22],
#          [ 21,  16,  18]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2943.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.4535655975341797, 'inference': 6.753206253051758, 'postprocess': 1.4460086822509766},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[ 60,  60,  60],
#          [ 61,  61,  61],
#          [ 62,  62,  62],
#          ...,
#          [ 96, 100, 105],
#          [ 97, 101, 106],
#          [ 94,  98, 103]],
#
#         [[ 59,  59,  59],
#          [ 59,  59,  59],
#          [ 60,  60,  60],
#          ...,
#          [ 96, 100, 105],
#          [ 96, 100, 105],
#          [ 93,  97, 102]],
#
#         [[ 60,  60,  60],
#          [ 60,  60,  60],
#          [ 60,  60,  60],
#          ...,
#          [ 96, 100, 105],
#          [ 95,  99, 104],
#          [ 91,  95, 100]],
#
#         ...,
#
#         [[ 95, 116, 124],
#          [ 98, 119, 127],
#          [103, 124, 132],
#          ...,
#          [117, 140, 156],
#          [123, 146, 162],
#          [128, 151, 167]],
#
#         [[ 99, 120, 128],
#          [ 99, 120, 128],
#          [102, 123, 131],
#          ...,
#          [151, 173, 191],
#          [149, 171, 189],
#          [142, 166, 184]],
#
#         [[103, 124, 132],
#          [101, 122, 130],
#          [100, 121, 129],
#          ...,
#          [ 40,  62,  80],
#          [ 22,  46,  66],
#          [  4,  28,  48]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2945.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.3572444915771484, 'inference': 6.876707077026367, 'postprocess': 1.6074180603027344},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[171, 170, 174],
#          [185, 184, 188],
#          [189, 187, 193],
#          ...,
#          [ 21,  31,  41],
#          [ 23,  33,  43],
#          [ 29,  39,  49]],
#
#         [[116, 112, 117],
#          [146, 145, 149],
#          [179, 178, 182],
#          ...,
#          [ 24,  34,  44],
#          [ 26,  36,  46],
#          [ 31,  41,  51]],
#
#         [[103,  98, 100],
#          [104, 101, 103],
#          [118, 115, 117],
#          ...,
#          [ 27,  37,  47],
#          [ 26,  36,  46],
#          [ 28,  38,  48]],
#
#         ...,
#
#         [[173, 230, 251],
#          [173, 230, 251],
#          [173, 230, 251],
#          ...,
#          [ 72,  86,  98],
#          [ 73,  87,  99],
#          [ 73,  87,  99]],
#
#         [[173, 230, 251],
#          [173, 230, 251],
#          [173, 230, 251],
#          ...,
#          [ 68,  82,  94],
#          [ 69,  83,  95],
#          [ 70,  84,  96]],
#
#         [[173, 230, 251],
#          [173, 230, 251],
#          [173, 230, 251],
#          ...,
#          [ 67,  81,  93],
#          [ 69,  83,  95],
#          [ 71,  85,  97]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2946.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 3.626585006713867, 'inference': 12.003183364868164, 'postprocess': 2.402782440185547},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[ 80,  76,  81],
#          [ 87,  83,  88],
#          [ 96,  92,  97],
#          ...,
#          [ 59,  60,  64],
#          [ 58,  59,  63],
#          [ 58,  59,  63]],
#
#         [[ 80,  76,  81],
#          [ 83,  79,  84],
#          [ 88,  84,  89],
#          ...,
#          [ 57,  58,  62],
#          [ 57,  58,  62],
#          [ 56,  57,  61]],
#
#         [[ 85,  81,  86],
#          [ 83,  79,  84],
#          [ 84,  80,  85],
#          ...,
#          [ 57,  58,  62],
#          [ 57,  58,  62],
#          [ 57,  58,  62]],
#
#         ...,
#
#         [[136, 148, 160],
#          [136, 148, 160],
#          [137, 149, 161],
#          ...,
#          [ 21,  26,  29],
#          [ 18,  25,  28],
#          [ 17,  24,  27]],
#
#         [[138, 150, 162],
#          [138, 150, 162],
#          [139, 151, 163],
#          ...,
#          [ 23,  28,  31],
#          [ 20,  25,  28],
#          [ 18,  23,  26]],
#
#         [[139, 151, 163],
#          [139, 151, 163],
#          [140, 152, 164],
#          ...,
#          [ 18,  23,  26],
#          [ 18,  23,  26],
#          [ 18,  23,  26]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2950.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 3.6079883575439453, 'inference': 11.271238327026367, 'postprocess': 2.057313919067383},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[ 73,  74,  64],
#          [ 67,  68,  58],
#          [ 74,  73,  63],
#          ...,
#          [ 28,  26,  26],
#          [ 28,  26,  26],
#          [ 27,  25,  25]],
#
#         [[ 72,  73,  63],
#          [ 67,  68,  58],
#          [ 75,  74,  64],
#          ...,
#          [ 26,  26,  26],
#          [ 27,  25,  25],
#          [ 22,  22,  22]],
#
#         [[ 72,  73,  63],
#          [ 67,  68,  58],
#          [ 76,  75,  65],
#          ...,
#          [ 22,  24,  25],
#          [ 21,  20,  22],
#          [ 17,  19,  20]],
#
#         ...,
#
#         [[164, 178, 196],
#          [164, 178, 196],
#          [164, 178, 196],
#          ...,
#          [  8,  12,  13],
#          [  7,  11,  12],
#          [  8,  12,  13]],
#
#         [[163, 177, 195],
#          [163, 177, 195],
#          [163, 177, 195],
#          ...,
#          [  4,   8,   9],
#          [  3,   7,   8],
#          [  6,  10,  11]],
#
#         [[162, 176, 194],
#          [162, 176, 194],
#          [162, 176, 194],
#          ...,
#          [  1,   5,   6],
#          [  0,   4,   5],
#          [  4,   8,   9]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2951.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.353191375732422, 'inference': 6.705999374389648, 'postprocess': 1.3701915740966797},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[ 42,  46,  47],
#          [ 42,  46,  47],
#          [ 42,  46,  47],
#          ...,
#          [102, 132, 167],
#          [102, 132, 167],
#          [102, 132, 167]],
#
#         [[ 42,  46,  47],
#          [ 42,  46,  47],
#          [ 42,  46,  47],
#          ...,
#          [ 98, 130, 165],
#          [100, 129, 166],
#          [ 98, 130, 165]],
#
#         [[ 42,  46,  47],
#          [ 42,  46,  47],
#          [ 42,  46,  47],
#          ...,
#          [ 98, 132, 168],
#          [100, 131, 170],
#          [ 97, 131, 167]],
#
#         ...,
#
#         [[ 35,  37,  45],
#          [ 33,  35,  43],
#          [ 33,  35,  43],
#          ...,
#          [ 19,  29,  36],
#          [ 20,  30,  37],
#          [ 15,  25,  32]],
#
#         [[ 36,  38,  46],
#          [ 30,  32,  40],
#          [ 25,  27,  35],
#          ...,
#          [ 14,  24,  31],
#          [ 15,  25,  32],
#          [  9,  19,  26]],
#
#         [[ 32,  34,  42],
#          [ 23,  25,  33],
#          [ 15,  17,  25],
#          ...,
#          [ 19,  29,  36],
#          [ 20,  30,  37],
#          [ 13,  23,  30]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2953.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.349853515625, 'inference': 6.992340087890625, 'postprocess': 1.4295578002929688},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[ 48,  57,  67],
#          [ 45,  54,  64],
#          [ 44,  53,  63],
#          ...,
#          [106, 147, 196],
#          [106, 147, 196],
#          [106, 147, 196]],
#
#         [[ 47,  56,  66],
#          [ 46,  55,  65],
#          [ 45,  54,  64],
#          ...,
#          [106, 147, 196],
#          [106, 147, 196],
#          [106, 147, 196]],
#
#         [[ 46,  55,  65],
#          [ 47,  56,  66],
#          [ 48,  57,  67],
#          ...,
#          [105, 146, 195],
#          [105, 146, 195],
#          [105, 146, 195]],
#
#         ...,
#
#         [[ 39,  32,  39],
#          [ 34,  30,  36],
#          [ 19,  22,  27],
#          ...,
#          [ 30,  40,  47],
#          [ 30,  38,  45],
#          [ 27,  35,  42]],
#
#         [[ 28,  21,  28],
#          [ 22,  18,  24],
#          [ 24,  27,  32],
#          ...,
#          [ 28,  40,  46],
#          [ 27,  37,  44],
#          [ 24,  34,  41]],
#
#         [[ 13,   6,  13],
#          [ 10,   6,  12],
#          [ 40,  43,  48],
#          ...,
#          [ 33,  45,  51],
#          [ 32,  42,  49],
#          [ 30,  40,  47]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2954.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.341032028198242, 'inference': 6.81304931640625, 'postprocess': 1.4429092407226562},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[ 70,  75,  76],
#          [ 70,  75,  76],
#          [ 71,  76,  77],
#          ...,
#          [240, 253, 255],
#          [240, 253, 255],
#          [238, 253, 255]],
#
#         [[ 70,  75,  76],
#          [ 70,  75,  76],
#          [ 71,  76,  77],
#          ...,
#          [244, 254, 254],
#          [242, 254, 255],
#          [242, 254, 254]],
#
#         [[ 71,  76,  77],
#          [ 71,  76,  77],
#          [ 72,  77,  78],
#          ...,
#          [248, 254, 253],
#          [249, 253, 254],
#          [249, 254, 253]],
#
#         ...,
#
#         [[160, 174, 180],
#          [160, 174, 180],
#          [159, 173, 179],
#          ...,
#          [159, 171, 177],
#          [159, 171, 177],
#          [159, 171, 177]],
#
#         [[143, 157, 163],
#          [146, 160, 166],
#          [150, 164, 170],
#          ...,
#          [158, 170, 176],
#          [158, 170, 176],
#          [157, 169, 175]],
#
#         [[102, 116, 122],
#          [107, 121, 127],
#          [116, 130, 136],
#          ...,
#          [154, 166, 172],
#          [153, 165, 171],
#          [153, 165, 171]]], dtype=uint8)
#  orig_shape: (768, 1024)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/IMG_2969.JPG'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.3343563079833984, 'inference': 7.3986053466796875, 'postprocess': 1.4603137969970703},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'class_0', 1: 'class_1'}
#  obb: None
#  orig_img: array([[[ 35,  38,  46],
#          [ 34,  37,  45],
#          [ 31,  37,  44],
#          ...,
#          [105, 117, 127],
#          [106, 118, 128],
#          [106, 118, 128]],
#
#         [[ 36,  42,  49],
#          [ 35,  41,  48],
#          [ 33,  39,  46],
#          ...,
#          [104, 116, 126],
#          [105, 117, 127],
#          [105, 117, 127]],
#
#         [[ 50,  57,  66],
#          [ 48,  55,  64],
#          [ 45,  52,  61],
#          ...,
#          [104, 116, 126],
#          [104, 116, 126],
#          [103, 115, 125]],
#
#         ...,
#
#         [[177, 193, 209],
#          [174, 190, 206],
#          [170, 186, 202],
#          ...,
#          [173, 189, 205],
#          [167, 183, 200],
#          [172, 190, 207]],
#
#         [[173, 189, 205],
#          [169, 185, 201],
#          [166, 182, 198],
#          ...,
#          [162, 178, 195],
#          [179, 197, 214],
#          [186, 204, 221]],
#
#         [[174, 190, 206],
#          [170, 186, 202],
#          [166, 182, 198],
#          ...,
#          [178, 194, 211],
#          [177, 195, 212],
#          [178, 196, 213]]], dtype=uint8)
#  orig_shape: (768, 768)
#  path: '/content/drive/MyDrive/AI_CHALLENGE_2/TestingDatasetForAIJC/ai_challenge_2/0/pipes2.jpeg'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.74658203125, 'inference': 8.125782012939453, 'postprocess': 1.4896392822265625}]
